# %%
import cv2
import pytesseract
from matplotlib import pyplot as plt

# %%
# !pip3 install pytesseract

# read image

img = cv2.imread('test-image-code.png')

# %%
# configurations
config = ('-l eng')
# config = ('-l eng --oem 1 --psm 3')

# %%
# pytessercat
pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files/Tesseract-OCR/tesseract.exe'

# %%
text = pytesseract.image_to_string(img, config=config)

# %%
# print text
# text = text.split('\n')
print(text)
# Out:
# => exporting to image 7.58
# > exporting layers 7.58
# > writing image sha256:29f2fbebe59907de219a067ae49ca80d1349ad3cb2c8c862e0cC312978da23 0.0s
# => naming to docker.io/library/mp11_docker 0.0s
#
# Use ‘docker scan’ to run Snyk tests against images to find vulnerabilities and learn how to fix t
# hem
#
# PS D:\UIUC\Senior\CS498CCU\MP11_new\MP11_Storm Template\Docker> docker run -it -v D:\UIUC\Senior\
# CSA498CCU\MP11_new\MP11_Storm Template: /mp11 mp11_docker bin/bash
#
# docker: Error response from daemon: OCI runtime create failed: container_linux.go:380: starting c
# container process caused: exec: "/mpii/entrypoint.sh": stat /mp11/entrypoint.sh: no such file or d
# irectory: unknown.
#
# PS D:\UIUC\Senior\CS498CCU\MP11_new\MP11 Storm Template\Docker>

# %%
plt.figure(figsize=(20,20))
plt.imshow(img)
